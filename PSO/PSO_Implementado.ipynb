# %%
import numba
import numpy as np

# %% [markdown]
# **Funciones de prueba:**

# %%
@numba.njit
def Sphere(arr):
    """
    Esta función recibe como parámetro un vector de n entradas, ingresado como un np.array,
    y devuelve el escalar que resulta de evaluar la función de la esfera en el vector.
    Se usa en el intervalo de búsqueda [-5.12, 5.12] y su óptimo global está en f([0,..,0])=0

    Ejemplo de uso:
        > Sphere(np.array([0, 0]))

        > 0
    """
    suma = 0.0  # Usar un float para la suma
    for x in arr:
        suma += x ** 2
    return suma

intervaloSphere = (-5.12, 5.12)


# Ejemplo de uso (y compilación AOT)
resultado = Sphere(np.array([1.0, 2.0, 3.0]))
print(resultado)
# Out:
# 14.0

# %%
@numba.njit
def Ackley(arr):
    """
    Esta función recibe como parámetro un vector de n entradas, ingresado como un np.array,
    y devuelve el escalar que resulta de evaluar la función Ackley en el vector.
    Se usa en el intervalo de búsqueda [-30, 30] y su óptimo global está en f([0,..,0])=0.

    Ejemplo de uso:
        > Ackley(np.array([0, 0]))

        > 0
    """
    suma1 = 0.0
    suma2 = 0.0
    n = arr.shape[0]  # Usar el tamaño del array de NumPy
    for x in arr:
        suma1 += x ** 2
        suma2 += np.cos(2 * np.pi * x)
    
    # Calcular el resultado de la función Ackley
    term1 = 20 + np.exp(1) - 20 * np.exp(-0.2 * np.sqrt(suma1 / n))
    term2 = np.exp(suma2 / n)
    return term1 - term2

intervaloAckley = (-30, 30)

# Ejemplo de uso (y compilación AOT)
resultado = Ackley(np.array([0, 0]))
print(resultado)  # Debería imprimir un valor cercano a 0
# Out:
# -4.440892098500626e-16

# %%
@numba.njit
def Griewank(arr):
    """
    Esta función recibe como parámetro un vector de n entradas, ingresado como un np.array,
    y devuelve el escalar que resulta de evaluar la función Griewank en el vector.
    Se usa en el intervalo de búsqueda [-600, 600] y su óptimo global está en f([0,..,0])=0.

    Ejemplo de uso:
        > Griewank(np.array([0, 0]))

        > 0
    """
    suma = 0.0
    m = 1.0  # Inicializar en 1 para la multiplicación de cosenos
    n = arr.shape[0]  # Obtener el número de elementos en el array

    for i in range(1, n + 1):
        x_i = arr[i - 1]  # Acceder al elemento en el índice correspondiente
        suma += (x_i ** 2) / 4000.0  # Sumar la parte de la función
        m *= np.cos(x_i / np.sqrt(i))  # Multiplicar por el coseno

    return 1 + suma - m

intervaloGriewank = (-600, 600)

# Ejemplo de uso (y compilación AOT)
resultado = Griewank(np.array([0, 0]))
print(resultado)  # Debería imprimir 0.0
# Out:
# 0.0

# %%
@numba.njit
def Rastrigin(arr):
    """
    Esta función recibe como parámetro un vector de n entradas, ingresado como un np.array,
    y devuelve el escalar que resulta de evaluar la función de Rastrigin en el vector.
    Tiene mínimo global en f([0,..,0]).

    Ejemplo de uso:
        > Rastrigin(np.array([2, 3, 6, 7]))

        > 98.0
    """
    n = arr.shape[0]  # Obtener el número de elementos en el array
    suma = 0.0

    for x in arr:
        suma += x ** 2 - 10 * np.cos(2 * np.pi * x)  # Calcular la suma de la función Rastrigin

    return 10 * n + suma  # Retornar el resultado final

intervaloRastrigin = (-5.12, 5.12)

# Ejemplo de uso (y compilación AOT)
resultado = Rastrigin(np.array([2, 3, 6, 7]))
print(resultado)  # Debería imprimir 98.0
# Out:
# 98.0

# %%
@numba.njit
def Rosenbrock(x):
    """
    Esta función recibe como parámetro un vector de n entradas, ingresado como un array de NumPy
    y devuelve el escalar que resulta de evaluar la función de Rosenbrock en el vector.
    Tiene un mínimo global en f(1, ..., 1).

    Ejemplo de uso:
      > Rosenbrock(np.array([1, 1]))
      > 0
    """
    n = x.shape[0]  # Obtener el tamaño del array
    suma = 0.0
    for i in range(n - 1):
        suma += 100 * (x[i + 1] - (x[i]) ** 2) ** 2 + (x[i] - 1) ** 2
    return suma

intervaloRosenbrock = (-2.048, 2.048)

# Ejemplo de uso (y compilación AOT)
resultado = Rosenbrock(np.array([1, 1]))
print(resultado)  # Debería imprimir 0.0
# Out:
# 0.0

# %% [markdown]
# **Parámetros:**

# %%
numParticulas = 70
maxIteraciones = 1000
dimension = 10
w = 0.729
c1 = 1.49445
c2 = 1.49445 
funcionObjetivo = Rastrigin
intervalo = intervaloRastrigin

# %% [markdown]
# **Implementación PSO**

# %%
@numba.njit
def PSO(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2):
    
    # Inicializamos nuestra población inicial de partículas y velocidades:
    a,b = intervalo
    particulas = np.random.uniform(a, b, (numParticulas, dimension))
    velocidades = np.zeros((numParticulas, dimension))

    # Inicializamos las mejores posiciones y mejores valores:
    mejores_posiciones = np.copy(particulas) 
    
    mejores_aptitudes  = np.empty(numParticulas)
    for i in range(numParticulas):
        mejores_aptitudes[i] = funcionObjetivo(particulas[i])

    mejor_posicion_enjambre = mejores_posiciones[np.argmin(mejores_aptitudes)]
    mejor_aptitud_enjambre = np.min(mejores_aptitudes)

    # Iteramos hasta maxIteraciones, actualizando la velocidad y la posición de cada partícula en cada iteración:
    for _ in range(maxIteraciones):
        # Actualizamos las velocidades:
        r1 = np.random.uniform(0, 1, (numParticulas, dimension))
        r2 = np.random.uniform(0, 1, (numParticulas, dimension))
        for i in range(numParticulas):
            for d in range(dimension):
                velocidades[i, d] = (w * velocidades[i, d] + c1 * r1[i, d] * (mejores_posiciones[i, d] - particulas[i, d]) + c2 * r2[i, d] * (mejor_posicion_enjambre[d] - particulas[i, d]))

        # Actualizamos las posiciones:
        for i in range(numParticulas):
            for d in range(dimension):
                particulas[i, d] += velocidades[i, d]

        # Evaluamos la aptitud de cada partícula:
        evaluaciones_de_aptitud = np.empty(numParticulas)
        for i in range(numParticulas):
            evaluaciones_de_aptitud[i] = funcionObjetivo(particulas[i])

        # Actualizamos las posiciones y las aptitudes:
        for i in range(numParticulas):
            if evaluaciones_de_aptitud[i] < mejores_aptitudes[i]:
                mejores_aptitudes[i] = evaluaciones_de_aptitud[i]
                mejores_posiciones[i] = particulas[i]

        # Actualizamos la mejor posición global si es que encontramos una mejor:
        mejor_aptitud_actual = np.min(evaluaciones_de_aptitud)
        if mejor_aptitud_actual < mejor_aptitud_enjambre:
            mejor_aptitud_enjambre = mejor_aptitud_actual
            mejor_posicion_enjambre = particulas[np.argmin(evaluaciones_de_aptitud)]
    
    # Retornamos la mejor solución encontrada por el PSO:
    return mejor_posicion_enjambre, mejor_aptitud_enjambre

# %%
PSO(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2)
# Out:
# (array([-2.78511345e-09, -4.86045870e-10,  4.66731648e-09,  1.22319179e-10,
#          1.16191658e-09,  6.84645662e-09, -3.71762246e-10, -9.94958630e-01,
#         -9.94958639e-01, -9.94958640e-01]),
#  2.9848771712798907)

# %%
numParticulas = 70
maxIteraciones = 1000
dimension = 10
w = 0.729
c1 = 1.49445
c2 = 1.49445 
funcionObjetivo = Rosenbrock
intervalo = intervaloRosenbrock

PSO(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2)
# Out:
# (array([1.00043913, 1.00113574, 1.00227934, 1.00456311, 1.00950058,
#         1.01913241, 1.03813089, 1.077247  , 1.16029399, 1.34602214]),
#  0.03367485244627191)

# %%
numParticulas = 70 # Misma población que en AG para que la comparación sea justa.
maxIteraciones = 1000 # Mismas iteraciones que en AG para que la comparación sea justa.
dimension = 10 # Misma dimensión que en AG para que la comparación sea justa.
w = 0.729
c1 = 1.49445
c2 = 1.49445 
funcionObjetivo = Ackley
intervalo = intervaloAckley

PSO(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2)
# Out:
# (array([ 1.10990928e-12,  1.13417880e-12,  1.28659354e-12,  1.04817149e-11,
#          2.05646379e-12,  1.92473812e-12,  2.22046771e-14, -3.22883344e-12,
#         -1.96553070e-12, -3.23530135e-12]),
#  8.064215961667287e-12)

# %%
numParticulas = 70 # Misma población que en AG para que la comparación sea justa.
maxIteraciones = 1000 # Mismas iteraciones que en AG para que la comparación sea justa.
dimension = 10 # Misma dimensión que en AG para que la comparación sea justa.
w = 0.729
c1 = 1.49445
c2 = 1.49445 
funcionObjetivo = Griewank
intervalo = intervaloGriewank

PSO(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2)
# Out:
# (array([-3.14002225e+00,  4.43844337e+00, -8.42878367e-09,  6.27064096e+00,
#         -7.00729236e+00, -1.27585343e-08, -8.78335977e-09, -8.85035719e+00,
#         -1.82110578e-08,  9.88515382e+00]),
#  0.07376398054413591)

# %% [markdown]
# **PSO para análisis estadístico:**

# %%
@numba.njit
def PSO_Estadistico(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2):

    # Inicializamos listas donde guardaremos las iteraciones 
    aptitud_promedio = np.zeros(maxIteraciones)
    aptitud_mejor = np.zeros(maxIteraciones)
    
    # Inicializamos nuestra población inicial de partículas y velocidades:
    a, b = intervalo
    particulas = np.random.uniform(a, b, (numParticulas, dimension))
    velocidades = np.zeros((numParticulas, dimension))

    # Inicializamos las mejores posiciones y mejores valores:
    mejores_posiciones = np.copy(particulas) 
    mejores_aptitudes = np.empty(numParticulas)
    for i in range(numParticulas):
        mejores_aptitudes[i] = funcionObjetivo(particulas[i])

    mejor_posicion_enjambre = mejores_posiciones[np.argmin(mejores_aptitudes)]
    mejor_aptitud_enjambre = np.min(mejores_aptitudes)
    mejor_aptitud_factible = 0

    # Contador para verificar cuántas veces la mejor solución global salió del rango
    contador_fuera_de_rango = 0

    # Iteramos hasta maxIteraciones, actualizando la velocidad y la posición de cada partícula en cada iteración:
    for iteracion in range(maxIteraciones):
        # Actualizamos las velocidades:
        r1 = np.random.uniform(0, 1, (numParticulas, dimension))
        r2 = np.random.uniform(0, 1, (numParticulas, dimension))
        for i in range(numParticulas):
            for d in range(dimension):
                velocidades[i, d] = (w * velocidades[i, d] + c1 * r1[i, d] * (mejores_posiciones[i, d] - particulas[i, d]) + c2 * r2[i, d] * (mejor_posicion_enjambre[d] - particulas[i, d]))

        # Actualizamos las posiciones:
        for i in range(numParticulas):
            for d in range(dimension):
                particulas[i, d] += velocidades[i, d]

        # Evaluamos la aptitud de cada partícula:
        evaluaciones_de_aptitud = np.empty(numParticulas)
        for i in range(numParticulas):
            evaluaciones_de_aptitud[i] = funcionObjetivo(particulas[i])

        # Actualizamos las posiciones y las aptitudes:
        for i in range(numParticulas):
            if evaluaciones_de_aptitud[i] < mejores_aptitudes[i]:
                mejores_aptitudes[i] = evaluaciones_de_aptitud[i]
                mejores_posiciones[i] = particulas[i]

        # Actualizamos la mejor posición global si es que encontramos una mejor:
        mejor_aptitud_actual = np.min(evaluaciones_de_aptitud)
        if mejor_aptitud_actual < mejor_aptitud_enjambre:
            mejor_aptitud_enjambre = mejor_aptitud_actual
            mejor_posicion_enjambre = particulas[np.argmin(evaluaciones_de_aptitud)]

        # Verificamos si la mejor posición global está dentro del rango
        fuera_del_rango = False
        for d in range(dimension):
            if mejor_posicion_enjambre[d] < a or mejor_posicion_enjambre[d] > b:
                fuera_del_rango = True
                break

        # Si está fuera del rango, incrementamos el contador
        if fuera_del_rango:
            contador_fuera_de_rango += 1
        # Si sí está en el rango:
        else:
            mejor_aptitud_factible = mejor_aptitud_enjambre

        # Guardamos la mejor evaluación de la generación y la evaluación promedio:
        aptitud_mejor[iteracion] = mejor_aptitud_enjambre
        aptitud_promedio[iteracion] = np.mean(evaluaciones_de_aptitud)

    # Verificamos si en la última iteración la mejor solución global está dentro del intervalo
    ultima_iteracion_en_rango = True
    for d in range(dimension):
        if mejor_posicion_enjambre[d] < a or mejor_posicion_enjambre[d] > b:
            ultima_iteracion_en_rango = False
            break

    if ultima_iteracion_en_rango == True: # Si la última iteración sí se quedó en el espacio de búsqueda:
        # Retornamos la lista de las mejores soluciones encontradas a cada generación, la lista de los promedios generacionales, el contador de las veces que la mejor posición estuvo fuera del rango, y si la última iteración estuvo en rango y la última solución factible encontrada (que va a ser la misma que la obtenida en la iteración final).
        return aptitud_mejor, aptitud_promedio, contador_fuera_de_rango, ultima_iteracion_en_rango, mejor_aptitud_factible
    else: # En caso de que la última iteracion se haya salido del espacio de búsqueda:
        # Retornamos la lista de las mejores soluciones encontradas a cada generación, la lista de los promedios generacionales, el contador de las veces que la mejor posición estuvo fuera del rango, si la última iteración estuvo en rango y la última solución factible encontrada.
        return aptitud_mejor, aptitud_promedio, contador_fuera_de_rango, ultima_iteracion_en_rango, mejor_aptitud_factible

# %%
PSO_Estadistico(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2)
# Out:
# (array([66.42605519, 38.07479319, 32.52528901, 24.83363209, 24.83363209,
#         24.83363209, 17.8951097 ,  5.85940971,  5.05858089,  5.05858089,
#          5.05858089,  5.05858089,  5.05858089,  5.05858089,  5.05858089,
#          5.05858089,  5.05858089,  5.05858089,  4.71510914,  3.4803526 ,
#          3.25887952,  2.3440466 ,  1.78949451,  1.57646501,  1.57646501,
#          1.57646501,  1.57646501,  1.57646501,  1.57646501,  1.57646501,
#          1.57646501,  1.57646501,  1.57646501,  1.57646501,  1.57646501,
#          1.57646501,  1.47868593,  1.47868593,  1.47868593,  1.26814819,
#          1.26801683,  1.26801683,  1.17836806,  1.06722628,  1.06722628,
#          1.06722628,  1.06722628,  1.06722628,  1.06722628,  0.88742105,
#          0.88742105,  0.88742105,  0.88742105,  0.88742105,  0.88742105,
#          0.88742105,  0.88742105,  0.88742105,  0.88742105,  0.88742105,
#          0.88742105,  0.88742105,  0.88742105,  0.88742105,  0.88742105,
#          0.88742105,  0.88742105,  0.82078874,  0.82078874,  0.82078874,
#          0.82078874,  0.82078874,  0.82078874,  0.82078874,  0.82078874,
#          0.82078874,  0.82078874,  0.82078874,  0.82078874,  0.82078874,
#          0.82078874,  0.82078874,  0.48102735,  0.48102735,  0.48102735,
#          0.48102735,  0.48102735,  0.48102735,  0.48102735,  0.48102735,
#          0.48102735,  0.48102735,  0.48102735,  0.48102735,  0.48102735,
#          0.48102735,  0.48102735,  0.48102735,  0.34193135,  0.34193135,
#          0.34193135,  0.34193135,  0.34193135,  0.34193135,  0.34193135,
#          0.34193135,  0.34193135,  0.34193135,  0.34193135,  0.34193135,
#          0.34193135,  0.34193135,  0.34193135,  0.34193135,  0.34193135,
#          0.34193135,  0.34193135,  0.34193135,  0.34193135,  0.34193135,
#          0.34193135,  0.34193135,  0.34193135,  0.34193135,  0.31337307,
#          0.31337307,  0.31337307,  0.31337307,  0.28515812,  0.28515812,
#          0.28515812,  0.28515812,  0.28515812,  0.28515812,  0.28515812,
#          0.24616887,  0.24616887,  0.24616887,  0.24616887,  0.24616887,
#          0.24616887,  0.24616887,  0.24616887,  0.23565548,  0.23565548,
#          0.23565548,  0.23565548,  0.23565548,  0.23565548,  0.23565548,
#          0.23565548,  0.22461665,  0.22461665,  0.22461665,  0.22461665,
#          0.22461665,  0.22461665,  0.22461665,  0.22461665,  0.22461665,
#          0.22461665,  0.22461665,  0.22461665,  0.22461665,  0.22461665,
#          0.22461665,  0.22461665,  0.22461665,  0.22461665,  0.22461665,
#          0.22461665,  0.22461665,  0.22461665,  0.22461665,  0.18188973,
#          0.18188973,  0.18188973,  0.18188973,  0.18188973,  0.18188973,
#          0.18188973,  0.18188973,  0.18188973,  0.18188973,  0.18188973,
#          0.18188973,  0.18188973,  0.18188973,  0.18188973,  0.18188973,
#          0.17267354,  0.17267354,  0.17267354,  0.17267354,  0.17267354,
#          0.17267354,  0.17267354,  0.17267354,  0.17267354,  0.17267354,
#          0.17064881,  0.17064881,  0.17064881,  0.17064881,  0.17064881,
#          0.15666953,  0.14914512,  0.11933688,  0.11933688,  0.11933688,
#          0.11933688,  0.11520636,  0.10761297,  0.10761297,  0.10408354,
#          0.10408354,  0.10408354,  0.10042023,  0.10042023,  0.10042023,
#          0.10021704,  0.10021704,  0.10021704,  0.09566142,  0.09566142,
#          0.09566142,  0.09566142,  0.09566142,  0.09566142,  0.09566142,
#          0.0941124 ,  0.0941124 ,  0.0941124 ,  0.0941124 ,  0.09372902,
#          0.09372902,  0.09372902,  0.09372902,  0.09372902,  0.09372902,
#          0.09372902,  0.09372902,  0.09372902,  0.09372902,  0.09372902,
#          0.09372902,  0.09372902,  0.09372902,  0.09334225,  0.09334225,
#          0.09072059,  0.09032103,  0.09032103,  0.09032103,  0.09032103,
#          0.08977106,  0.08977106,  0.08977106,  0.08977106,  0.08977106,
#          0.08977106,  0.08977106,  0.08977106,  0.08977106,  0.08977106,
#          0.08971568,  0.08971568,  0.08971568,  0.08971568,  0.08971568,
#          0.08971568,  0.089576  ,  0.089545  ,  0.089545  ,  0.089545  ,
#          0.08944952,  0.08917538,  0.08897341,  0.08897341,  0.08897341,
#          0.08897341,  0.08897341,  0.08897341,  0.08892047,  0.08892047,
#          0.08892047,  0.08892047,  0.08892047,  0.08892047,  0.08892047,
#          0.08892047,  0.08892047,  0.08892047,  0.08892047,  0.08892047,
#          0.08892047,  0.08892047,  0.08892047,  0.08892047,  0.08892047,
#          0.08892047,  0.08892047,  0.08892047,  0.08892047,  0.08890634,
#          0.08890634,  0.08890634,  0.08890634,  0.08890634,  0.0888924 ,
#          0.0888924 ,  0.0888924 ,  0.08876853,  0.08875945,  0.08875945,
#          0.08875945,  0.08871262,  0.08871262,  0.08871262,  0.08871262,
#          0.08871262,  0.08871262,  0.08871262,  0.08863811,  0.08863811,
#          0.08863811,  0.08863811,  0.08863811,  0.08863811,  0.08863811,
#          0.08863811,  0.08863811,  0.08863811,  0.08863811,  0.08863811,
#          0.08861865,  0.08861865,  0.08861865,  0.08861865,  0.08861865,
#          0.0885964 ,  0.0885964 ,  0.0885964 ,  0.0885964 ,  0.0885964 ,
#          0.0885964 ,  0.0885964 ,  0.08858837,  0.08858837,  0.08858837,
#          0.08858837,  0.08858837,  0.08858837,  0.08858837,  0.08858837,
#          0.08858837,  0.08858837,  0.08857514,  0.08856284,  0.08856284,
#          0.08855905,  0.08855227,  0.0885509 ,  0.0885509 ,  0.0885509 ,
#          0.0885509 ,  0.08854871,  0.08854857,  0.08854857,  0.08854857,
#          0.08854857,  0.08854574,  0.08853507,  0.08853507,  0.08853507,
#          0.08853507,  0.08853507,  0.08853507,  0.08853507,  0.08853507,
#          0.08853507,  0.08853507,  0.08853507,  0.08853507,  0.08853507,
#          0.08853507,  0.08853507,  0.08853507,  0.08853507,  0.08853507,
#          0.08853461,  0.08852805,  0.08852805,  0.08852805,  0.08852805,
#          0.08852805,  0.08852805,  0.08852805,  0.08852762,  0.08852762,
#          0.08852762,  0.08852762,  0.08852762,  0.08852762,  0.08852686,
#          0.08852327,  0.08852273,  0.08852273,  0.08852273,  0.08852273,
#          0.08852273,  0.08852273,  0.08852273,  0.08852273,  0.08852273,
#          0.0885227 ,  0.0885227 ,  0.08852249,  0.08852249,  0.08852223,
#          0.08852223,  0.08852223,  0.08852223,  0.0885213 ,  0.0885213 ,
#          0.0885213 ,  0.08852088,  0.08852088,  0.08852088,  0.08852088,
#          0.08852045,  0.08852045,  0.08852045,  0.08852027,  0.08852027,
#          0.08852027,  0.08852021,  0.08852021,  0.08852021,  0.0885202 ,
#          0.08852005,  0.08851999,  0.08851963,  0.08851957,  0.08851957,
#          0.08851957,  0.08851957,  0.08851957,  0.08851957,  0.08851946,
#          0.08851946,  0.08851946,  0.08851946,  0.08851946,  0.08851946,
#          0.08851946,  0.08851946,  0.08851946,  0.08851946,  0.0885193 ,
#          0.0885193 ,  0.0885193 ,  0.0885193 ,  0.0885193 ,  0.0885193 ,
#          0.0885193 ,  0.0885193 ,  0.0885193 ,  0.0885193 ,  0.0885193 ,
#          0.08851929,  0.08851926,  0.08851926,  0.08851926,  0.08851926,
#          0.08851926,  0.08851926,  0.08851926,  0.08851926,  0.08851926,
#          0.08851925,  0.08851925,  0.08851925,  0.08851925,  0.08851925,
#          0.08851925,  0.08851925,  0.08851925,  0.08851925,  0.08851925,
#          0.08851923,  0.08851923,  0.08851923,  0.08851923,  0.08851922,
#          0.08851922,  0.08851922,  0.08851922,  0.08851922,  0.08851922,
#          0.08851922,  0.08851922,  0.08851922,  0.08851922,  0.08851922,
#          0.08851922,  0.08851922,  0.0885192 ,  0.0885192 ,  0.0885192 ,
#          0.0885192 ,  0.0885192 ,  0.0885192 ,  0.08851919,  0.08851919,
#          0.08851919,  0.08851919,  0.08851919,  0.08851919,  0.08851919,
#          0.08851919,  0.08851919,  0.08851919,  0.08851919,  0.08851919,
#          0.08851918,  0.08851918,  0.08851918,  0.08851918,  0.08851918,
#          0.08851918,  0.08851918,  0.08851918,  0.08851918,  0.08851918,
#          0.08851918,  0.08851918,  0.08851918,  0.08851918,  0.08851918,
#          0.08851918,  0.08851918,  0.08851918,  0.08851918,  0.08851918,
#          0.08851918,  0.08851918,  0.08851918,  0.08851918,  0.08851918,
#          0.08851918,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917,
#          0.08851917,  0.08851917,  0.08851917,  0.08851917,  0.08851917]),
#  array([1.84978255e+02, 2.88927545e+02, 1.48911646e+02, 1.61964462e+02,
#         1.39636448e+02, 1.44447686e+02, 1.31158002e+02, 9.55873249e+01,
#         1.00830559e+02, 7.92246135e+01, 8.92912740e+01, 6.85781669e+01,
#         8.10153901e+01, 5.80973093e+01, 7.19367974e+01, 5.82786145e+01,
#         5.02713099e+01, 5.34444396e+01, 3.89379164e+01, 5.52424754e+01,
#         3.28980970e+01, 4.40923069e+01, 2.97171006e+01, 4.05420456e+01,
#         3.69463932e+01, 2.85906674e+01, 2.88423137e+01, 3.25714518e+01,
#         4.64307941e+01, 1.81426834e+01, 2.68838869e+01, 3.46821890e+01,
#         2.06913787e+01, 2.02478092e+01, 1.38867992e+01, 1.80467818e+01,
#         1.89426425e+01, 1.75670762e+01, 1.73247051e+01, 1.81465771e+01,
#         2.12454195e+01, 1.76592742e+01, 3.56909742e+01, 9.94333795e+01,
#         1.61770159e+01, 5.53658358e+01, 2.55117785e+01, 8.39207298e+01,
#         2.50974221e+01, 3.23741968e+01, 2.42160077e+01, 5.46298107e+00,
#         1.02744284e+01, 5.43528810e+00, 3.38162173e+00, 3.25578418e+00,
#         3.95117423e+00, 2.88606818e+00, 5.43066350e+00, 2.51478829e+00,
#         3.79043114e+00, 2.41365926e+00, 3.50962811e+00, 2.79030196e+00,
#         2.05669727e+00, 2.28215139e+00, 2.36617148e+00, 1.73708032e+00,
#         1.88975997e+00, 1.71474137e+00, 1.79834731e+00, 1.90057963e+00,
#         1.48350002e+00, 1.78900371e+00, 1.60479927e+00, 1.65287384e+00,
#         1.50080183e+00, 1.41060662e+00, 1.42612738e+00, 1.41498305e+00,
#         1.44794039e+00, 1.32502313e+00, 1.55721605e+00, 1.58652301e+00,
#         1.98654908e+00, 1.52083307e+00, 1.55642916e+00, 1.45074528e+00,
#         1.50809275e+00, 1.41436244e+00, 1.56039100e+00, 1.39661304e+00,
#         1.35685409e+00, 1.32384535e+00, 1.31084641e+00, 1.29413830e+00,
#         1.32545320e+00, 1.34590533e+00, 1.32722252e+00, 1.28866238e+00,
#         1.39835980e+00, 1.33602556e+00, 1.47226406e+00, 1.37383078e+00,
#         1.27804347e+00, 1.37340610e+00, 1.26314175e+00, 1.29129839e+00,
#         1.27062349e+00, 1.29526521e+00, 1.23185230e+00, 1.23717523e+00,
#         1.18324766e+00, 1.22626859e+00, 1.24084507e+00, 1.17850724e+00,
#         1.15435766e+00, 1.21172244e+00, 1.18346922e+00, 1.18170842e+00,
#         1.16529724e+00, 1.11467318e+00, 1.11736177e+00, 1.08419225e+00,
#         1.13942562e+00, 1.11497669e+00, 1.12259473e+00, 1.15727486e+00,
#         1.09216122e+00, 1.08262712e+00, 1.10825701e+00, 1.13928419e+00,
#         1.10679639e+00, 1.10424328e+00, 1.08126418e+00, 1.11353990e+00,
#         1.09483964e+00, 1.10465244e+00, 1.06808304e+00, 1.08395329e+00,
#         1.06585042e+00, 1.05852864e+00, 1.08340933e+00, 9.98008581e-01,
#         1.20574025e+00, 1.18550981e+00, 1.17807399e+00, 1.17730906e+00,
#         1.26529911e+00, 1.20443243e+00, 1.22570103e+00, 1.16933030e+00,
#         1.27924062e+00, 1.23031330e+00, 1.12556646e+00, 1.23846529e+00,
#         1.25643339e+00, 1.18109647e+00, 1.12240890e+00, 1.14465270e+00,
#         1.14425050e+00, 1.14610027e+00, 1.16248175e+00, 1.26058217e+00,
#         1.27093031e+00, 1.38506579e+00, 1.09047631e+00, 1.25226950e+00,
#         1.12815782e+00, 1.14009661e+00, 1.15941885e+00, 1.20754048e+00,
#         1.17416854e+00, 1.27534034e+00, 1.13249041e+00, 1.15853244e+00,
#         1.08182405e+00, 1.21620542e+00, 1.12810948e+00, 1.13914572e+00,
#         1.15090072e+00, 1.20285013e+00, 1.19561736e+00, 1.12589697e+00,
#         1.00729121e+00, 1.17433875e+00, 1.13709251e+00, 1.16404021e+00,
#         1.13542902e+00, 1.13076609e+00, 1.13512253e+00, 1.13019235e+00,
#         1.18081640e+00, 1.04108018e+00, 1.09688898e+00, 1.05933046e+00,
#         1.13199113e+00, 1.11283651e+00, 1.02398817e+00, 1.12241333e+00,
#         1.04744534e+00, 1.00973576e+00, 9.79745551e-01, 9.15253351e-01,
#         9.57114630e-01, 9.62643322e-01, 9.64871571e-01, 9.03058211e-01,
#         8.79418540e-01, 8.98256522e-01, 9.96708068e-01, 8.95967600e-01,
#         8.07484752e-01, 8.39691183e-01, 9.06447801e-01, 8.89025249e-01,
#         7.73600159e-01, 8.20031814e-01, 7.99943285e-01, 7.25485614e-01,
#         8.17517721e-01, 8.04120976e-01, 7.28896759e-01, 7.42889174e-01,
#         8.29817403e-01, 7.49805920e-01, 6.87318742e-01, 7.21654039e-01,
#         7.02242058e-01, 6.46986056e-01, 7.32086816e-01, 7.94112797e-01,
#         7.66098652e-01, 6.70538861e-01, 6.90615182e-01, 6.61405422e-01,
#         7.56138968e-01, 6.17438219e-01, 6.94286045e-01, 6.60432414e-01,
#         7.34864229e-01, 6.81671173e-01, 5.43492648e-01, 6.63829285e-01,
#         5.91669378e-01, 5.81584356e-01, 6.60849446e-01, 5.53853291e-01,
#         5.61725742e-01, 5.58227438e-01, 5.35886136e-01, 5.57126819e-01,
#         5.32302295e-01, 5.70733846e-01, 5.52839356e-01, 4.62748913e-01,
#         5.01733659e-01, 4.88808883e-01, 4.61549284e-01, 4.43029832e-01,
#         4.85549916e-01, 4.89757584e-01, 4.24558358e-01, 4.37124605e-01,
#         4.39999773e-01, 4.41362019e-01, 4.46440827e-01, 3.94501969e-01,
#         4.26485549e-01, 3.78955250e-01, 3.78831531e-01, 3.79676076e-01,
#         3.85808897e-01, 3.93484078e-01, 4.00892850e-01, 3.63525469e-01,
#         3.62175695e-01, 3.94518892e-01, 3.60585817e-01, 3.62602295e-01,
#         3.47288376e-01, 3.41900521e-01, 3.38230521e-01, 3.06345930e-01,
#         3.06260301e-01, 2.89990646e-01, 3.36012185e-01, 3.74556033e-01,
#         3.35669443e-01, 2.93537312e-01, 3.50017023e-01, 3.31776496e-01,
#         3.31388715e-01, 3.35235436e-01, 3.16966257e-01, 3.08006225e-01,
#         3.27181471e-01, 2.63249494e-01, 3.11950498e-01, 2.87302081e-01,
#         3.36836448e-01, 2.65778706e-01, 3.07545852e-01, 3.15103381e-01,
#         2.99188441e-01, 2.93651579e-01, 2.72760720e-01, 3.01451079e-01,
#         2.91425349e-01, 2.61196920e-01, 3.03877658e-01, 2.76397997e-01,
#         2.71512356e-01, 2.91886428e-01, 2.84351031e-01, 2.85885352e-01,
#         3.33980791e-01, 3.07258472e-01, 3.12830921e-01, 2.83862614e-01,
#         2.61375238e-01, 2.91552902e-01, 2.85785002e-01, 3.09404463e-01,
#         2.47405610e-01, 3.00978073e-01, 3.03260887e-01, 3.15486525e-01,
#         2.99714434e-01, 2.91923547e-01, 2.56604927e-01, 2.48727863e-01,
#         3.09318608e-01, 2.83358692e-01, 2.55249407e-01, 2.55607517e-01,
#         2.76252093e-01, 3.12591138e-01, 2.86738854e-01, 2.92823849e-01,
#         2.25496382e-01, 2.49968750e-01, 2.53207443e-01, 2.88611261e-01,
#         2.29169624e-01, 2.57029633e-01, 2.29590857e-01, 2.59667916e-01,
#         2.83183699e-01, 2.74247275e-01, 2.47071027e-01, 2.40512439e-01,
#         2.61678992e-01, 2.73278452e-01, 2.59709730e-01, 2.83115745e-01,
#         2.42252367e-01, 2.24857314e-01, 3.00248330e-01, 1.93288143e-01,
#         2.64247222e-01, 2.56592246e-01, 2.61391383e-01, 2.58628405e-01,
#         2.28067217e-01, 2.26770340e-01, 2.33996641e-01, 2.71299055e-01,
#         2.57687527e-01, 3.00843405e-01, 2.77822719e-01, 2.53223876e-01,
#         2.97622043e-01, 2.07188227e-01, 2.32834947e-01, 2.02601317e-01,
#         2.22682886e-01, 2.29350155e-01, 1.95746220e-01, 2.58203253e-01,
#         2.15838291e-01, 2.13751966e-01, 1.94099391e-01, 2.05561735e-01,
#         2.30301053e-01, 1.95356558e-01, 2.12786251e-01, 2.02902870e-01,
#         1.91427768e-01, 1.63167246e-01, 1.97381444e-01, 1.87966083e-01,
#         1.83784331e-01, 2.03100846e-01, 2.02561715e-01, 2.08146372e-01,
#         1.77806415e-01, 2.03610099e-01, 1.58886598e-01, 1.87415434e-01,
#         2.34055175e-01, 1.89922402e-01, 2.02535632e-01, 2.19415579e-01,
#         1.94250149e-01, 2.10107792e-01, 2.25030563e-01, 1.72064787e-01,
#         1.58257202e-01, 1.86753798e-01, 1.73503019e-01, 1.63644370e-01,
#         1.57867826e-01, 1.92087363e-01, 1.83881707e-01, 1.62619690e-01,
#         1.51648739e-01, 1.81969858e-01, 1.84913886e-01, 1.79157795e-01,
#         2.00293784e-01, 1.94663152e-01, 1.92322253e-01, 1.72491979e-01,
#         1.95078113e-01, 1.54842523e-01, 2.09083465e-01, 1.50087139e-01,
#         1.57557894e-01, 1.59221691e-01, 1.72378313e-01, 1.85823480e-01,
#         1.55257770e-01, 1.68679651e-01, 1.79774646e-01, 1.90172202e-01,
#         1.76861183e-01, 1.95484978e-01, 1.56068746e-01, 1.95769899e-01,
#         2.00295931e-01, 1.66614823e-01, 1.60027594e-01, 1.57286468e-01,
#         1.98148489e-01, 1.94521157e-01, 1.93077902e-01, 1.86713037e-01,
#         1.66538879e-01, 2.04316760e-01, 1.88119761e-01, 1.67951382e-01,
#         2.20987922e-01, 1.50280843e-01, 1.97949687e-01, 1.72509939e-01,
#         1.61644480e-01, 1.72764669e-01, 1.88986196e-01, 1.50385522e-01,
#         1.69962750e-01, 1.83259590e-01, 1.61246195e-01, 1.75437714e-01,
#         1.72458641e-01, 1.55733640e-01, 1.60283751e-01, 1.86656368e-01,
#         1.87234957e-01, 1.72837825e-01, 2.15025299e-01, 1.65213775e-01,
#         1.74569269e-01, 1.77193668e-01, 1.80581033e-01, 1.83933967e-01,
#         1.73941390e-01, 1.70874474e-01, 1.84382812e-01, 1.84434306e-01,
#         1.88069596e-01, 2.12780217e-01, 1.33144354e-01, 1.66430533e-01,
#         1.80518123e-01, 1.68298967e-01, 1.63241623e-01, 1.34405788e-01,
#         1.81340492e-01, 1.55624054e-01, 1.80387961e-01, 1.90412144e-01,
#         1.50123529e-01, 1.79688770e-01, 1.89345762e-01, 1.62009578e-01,
#         1.46563143e-01, 1.52452079e-01, 1.76216711e-01, 1.74098068e-01,
#         1.64242103e-01, 1.66778684e-01, 1.94610102e-01, 1.56463951e-01,
#         1.66988643e-01, 1.55485204e-01, 1.63948422e-01, 1.71015259e-01,
#         1.59533093e-01, 1.93659437e-01, 1.70016885e-01, 1.44682847e-01,
#         1.65086230e-01, 1.54461533e-01, 1.54276609e-01, 1.46929255e-01,
#         1.80023720e-01, 1.90781764e-01, 1.46498318e-01, 1.76580988e-01,
#         1.55853196e-01, 1.61403952e-01, 1.65260588e-01, 1.50635583e-01,
#         1.69590325e-01, 1.68843138e-01, 1.39921210e-01, 1.51544908e-01,
#         1.35116918e-01, 1.76170388e-01, 1.57288255e-01, 1.42978865e-01,
#         1.34754060e-01, 1.37478617e-01, 1.45713615e-01, 1.44179144e-01,
#         1.66980310e-01, 1.42216463e-01, 1.55611327e-01, 1.54784869e-01,
#         1.51822603e-01, 1.52651563e-01, 1.36363997e-01, 1.57633667e-01,
#         1.34949421e-01, 1.52152424e-01, 1.48390657e-01, 1.61064627e-01,
#         1.55313434e-01, 1.34616109e-01, 1.69370476e-01, 1.47410046e-01,
#         1.46781985e-01, 1.57278179e-01, 1.45764429e-01, 1.14310049e-01,
#         1.59821586e-01, 1.56698798e-01, 1.59724062e-01, 2.08312084e-01,
#         1.51289246e-01, 2.53567656e-01, 1.58229590e-01, 2.15613916e-01,
#         1.88255306e-01, 2.05894339e-01, 1.58374811e-01, 2.95220966e-01,
#         1.45161870e-01, 2.07939713e-01, 1.51226478e-01, 1.94386068e-01,
#         1.67714650e-01, 1.54366595e-01, 1.74082942e-01, 1.60361517e-01,
#         1.52762737e-01, 1.64622127e-01, 1.81214251e-01, 1.52598142e-01,
#         1.79603654e-01, 1.70600045e-01, 1.49997159e-01, 1.39207820e-01,
#         1.72167841e-01, 1.48886040e-01, 1.47991924e-01, 1.56361743e-01,
#         1.38541815e-01, 1.58405376e-01, 1.54965687e-01, 1.45637494e-01,
#         1.50888653e-01, 1.50816458e-01, 1.80858998e-01, 1.47234150e-01,
#         1.87134431e-01, 1.33992331e-01, 1.50954080e-01, 1.64529345e-01,
#         1.38549663e-01, 1.47143776e-01, 1.41939652e-01, 1.43192107e-01,
#         1.51041066e-01, 1.32169949e-01, 1.36269952e-01, 1.46780436e-01,
#         1.43846830e-01, 1.47808481e-01, 1.41414447e-01, 1.50745528e-01,
#         1.41838134e-01, 1.29484943e-01, 1.47389322e-01, 1.49869298e-01,
#         1.52720784e-01, 1.48192084e-01, 1.30509259e-01, 1.49818224e-01,
#         1.47946125e-01, 1.40401892e-01, 1.58109042e-01, 1.29967894e-01,
#         1.27951609e-01, 1.45003469e-01, 1.44903620e-01, 1.42868257e-01,
#         1.40225643e-01, 1.44973107e-01, 1.37160447e-01, 1.32837937e-01,
#         1.24688461e-01, 1.45993412e-01, 1.17583997e-01, 1.41417366e-01,
#         1.35831770e-01, 1.45378945e-01, 1.40826779e-01, 1.37145101e-01,
#         1.43957206e-01, 1.36608701e-01, 1.39797860e-01, 1.39086615e-01,
#         1.29679496e-01, 1.30618574e-01, 1.32014104e-01, 1.23193746e-01,
#         1.52613025e-01, 1.38021293e-01, 1.28846286e-01, 1.21173983e-01,
#         1.24967334e-01, 1.22607535e-01, 1.41150918e-01, 1.42285954e-01,
#         1.33403051e-01, 1.42096993e-01, 1.44732093e-01, 1.41284276e-01,
#         1.41098260e-01, 1.48911104e-01, 1.30986548e-01, 1.47217094e-01,
#         1.48276503e-01, 1.71080491e-01, 1.52901231e-01, 1.63903338e-01,
#         1.46224539e-01, 1.44590438e-01, 1.35031812e-01, 1.31869433e-01,
#         1.37135068e-01, 1.41926496e-01, 1.40013264e-01, 1.50089827e-01,
#         1.24905649e-01, 1.22962504e-01, 1.27917387e-01, 1.27395051e-01,
#         1.28583360e-01, 1.50176280e-01, 1.45190437e-01, 1.58362654e-01,
#         1.39032630e-01, 1.28006119e-01, 1.24100297e-01, 1.20407722e-01,
#         1.48810103e-01, 1.45422510e-01, 1.24320819e-01, 1.33501301e-01,
#         1.36574893e-01, 1.49808761e-01, 1.26210404e-01, 1.41840989e-01,
#         1.40372801e-01, 1.35884540e-01, 1.35533758e-01, 1.33522688e-01,
#         1.38328348e-01, 1.46329746e-01, 1.16290772e-01, 1.30518466e-01,
#         1.25543912e-01, 1.19471708e-01, 1.35821863e-01, 1.29047214e-01,
#         1.42424090e-01, 1.52223842e-01, 1.46940951e-01, 1.32522395e-01,
#         1.37570039e-01, 1.39929203e-01, 1.65022993e-01, 1.35303951e-01,
#         1.37119849e-01, 1.39242828e-01, 1.33636788e-01, 1.18965721e-01,
#         1.26806445e-01, 1.43746646e-01, 1.49086314e-01, 1.39194964e-01,
#         1.36700099e-01, 1.51627055e-01, 1.64490518e-01, 1.34809242e-01,
#         1.50690788e-01, 1.50619003e-01, 1.28723154e-01, 1.46959432e-01,
#         1.46795268e-01, 1.12775322e-01, 1.17372958e-01, 1.47364404e-01,
#         1.14803238e-01, 1.24923855e-01, 1.32701278e-01, 1.20623809e-01,
#         1.50474924e-01, 1.13928155e-01, 1.37125707e-01, 1.19566193e-01,
#         1.30982125e-01, 1.31965871e-01, 1.38914042e-01, 1.37598382e-01,
#         1.23858481e-01, 1.38972594e-01, 1.13179107e-01, 1.28822770e-01,
#         1.15746677e-01, 1.13938022e-01, 1.05556707e-01, 1.10535892e-01,
#         1.22222504e-01, 1.14087966e-01, 1.20433392e-01, 1.05104420e-01,
#         1.17248973e-01, 1.04385303e-01, 1.13278066e-01, 1.12144463e-01,
#         1.14459118e-01, 1.16861236e-01, 1.44756870e-01, 1.07258905e-01,
#         1.33433300e-01, 1.14531484e-01, 1.18134828e-01, 1.15083979e-01,
#         1.35453885e-01, 1.06837943e-01, 1.20638262e-01, 1.06381222e-01,
#         1.21861082e-01, 1.05345072e-01, 1.07710940e-01, 1.05634385e-01,
#         1.07631941e-01, 1.06709913e-01, 1.02515100e-01, 1.06766544e-01,
#         1.08835265e-01, 1.16673321e-01, 1.07112300e-01, 1.11329921e-01,
#         1.15709152e-01, 1.05872506e-01, 1.06882178e-01, 1.04413503e-01,
#         1.07001223e-01, 1.05252401e-01, 1.04562798e-01, 1.04150776e-01,
#         1.03103014e-01, 1.11248456e-01, 1.10214291e-01, 1.10333077e-01,
#         1.10764696e-01, 1.23825681e-01, 1.13740942e-01, 1.22633254e-01,
#         1.07144987e-01, 1.06992337e-01, 1.13125890e-01, 1.08445431e-01,
#         1.14362148e-01, 1.28846270e-01, 1.12920501e-01, 1.04801275e-01,
#         1.11404337e-01, 1.08719802e-01, 1.04088341e-01, 1.05127500e-01,
#         1.05236915e-01, 1.03243153e-01, 1.05550784e-01, 1.07442072e-01,
#         1.04057373e-01, 1.04825655e-01, 1.06031098e-01, 1.04264090e-01,
#         1.05022502e-01, 1.06554468e-01, 1.03373814e-01, 1.05893547e-01,
#         1.04015894e-01, 1.05963435e-01, 1.05660494e-01, 1.07346948e-01,
#         1.05888111e-01, 1.03942794e-01, 1.02585737e-01, 1.08498286e-01,
#         1.06169597e-01, 1.07075306e-01, 1.05450683e-01, 1.04306818e-01,
#         1.06040563e-01, 1.06752043e-01, 1.06226594e-01, 1.05821307e-01,
#         1.08908053e-01, 1.03972366e-01, 1.08729052e-01, 1.06680350e-01,
#         1.09466501e-01, 1.08773703e-01, 1.06097128e-01, 1.06854505e-01,
#         1.09422599e-01, 1.11119823e-01, 1.10346472e-01, 1.11793197e-01,
#         1.13552262e-01, 1.12925772e-01, 1.27105084e-01, 1.15736969e-01,
#         1.19322808e-01, 1.43806361e-01, 1.34462719e-01, 1.09893669e-01,
#         1.09910248e-01, 1.05957718e-01, 1.10861058e-01, 1.22764248e-01,
#         1.13844481e-01, 1.06878822e-01, 1.05751813e-01, 1.12142973e-01,
#         1.22409906e-01, 1.22349778e-01, 1.07612274e-01, 1.33899155e-01,
#         1.06771327e-01, 1.14025648e-01, 1.19020567e-01, 1.17694038e-01,
#         1.28144117e-01, 1.19130105e-01, 1.37431584e-01, 1.08566912e-01,
#         1.23508964e-01, 1.24053102e-01, 1.09981574e-01, 1.12571702e-01,
#         1.11979599e-01, 1.06876074e-01, 1.06919454e-01, 1.10019195e-01,
#         1.08445684e-01, 1.03996796e-01, 1.04012071e-01, 1.06578977e-01,
#         1.08656501e-01, 1.04541459e-01, 1.05439634e-01, 1.04473979e-01,
#         1.08421537e-01, 1.03415666e-01, 1.07622079e-01, 1.08269480e-01,
#         1.17729029e-01, 1.05693265e-01, 1.07647963e-01, 1.12053421e-01,
#         1.09685916e-01, 1.06894198e-01, 1.18192725e-01, 1.07328429e-01,
#         1.10334999e-01, 1.08707126e-01, 1.08470522e-01, 1.05076145e-01,
#         1.10761001e-01, 1.09091696e-01, 1.03940893e-01, 1.05169926e-01,
#         1.11143279e-01, 1.06851766e-01, 1.05109161e-01, 1.05043594e-01,
#         1.12055725e-01, 1.20855314e-01, 1.06200008e-01, 1.14609883e-01,
#         1.06767326e-01, 1.12334467e-01, 1.06542325e-01, 1.14264330e-01,
#         1.07411757e-01, 1.23171483e-01, 1.19076286e-01, 1.06149732e-01,
#         1.06131846e-01, 1.18487258e-01, 1.10532748e-01, 1.09864935e-01,
#         1.08668993e-01, 1.18150279e-01, 1.06139758e-01, 1.16571605e-01,
#         1.26015015e-01, 1.08674960e-01, 1.10198615e-01, 1.12884419e-01,
#         1.20314804e-01, 1.07140649e-01, 1.11034267e-01, 1.09727616e-01,
#         1.27778715e-01, 1.12940171e-01, 1.08721080e-01, 1.12096978e-01,
#         1.13980322e-01, 1.16887841e-01, 1.03902606e-01, 1.07622112e-01,
#         1.03933001e-01, 1.15530649e-01, 1.06305445e-01, 1.06600678e-01,
#         1.07004143e-01, 1.10152533e-01, 1.14341815e-01, 1.05109737e-01,
#         1.10372324e-01, 1.08951507e-01, 1.16830931e-01, 1.12602207e-01,
#         1.05758666e-01, 1.13138065e-01, 1.12933349e-01, 1.11631060e-01,
#         1.04159671e-01, 1.09184994e-01, 1.09497745e-01, 1.12015534e-01,
#         1.08387574e-01, 1.24417999e-01, 1.20557547e-01, 1.05591431e-01,
#         1.08494859e-01, 1.05355686e-01, 1.07796776e-01, 1.05601887e-01,
#         1.09877926e-01, 1.16293403e-01, 1.13463379e-01, 1.19916166e-01,
#         1.10211180e-01, 1.15536537e-01, 1.30353957e-01, 1.07665320e-01,
#         1.13378465e-01, 1.04725133e-01, 1.17001869e-01, 1.20695553e-01]),
#  0,
#  True,
#  0.08851916991129705)

# %% [markdown]
# **Análisis estadístico:**

# %%
import time
import numpy as np

# Función principal para ejecutar el algoritmo 30 veces y guardar los resultados
def ejecutar_algoritmo_y_guardar_resultados(ejecuciones=30):
    numParticulas = 70  # Tamaño de la población
    maxIteraciones = 1000  # Número de iteraciones
    dimension = 10  # Dimensionalidad del problema
    w = 0.729
    c1 = 1.49445
    c2 = 1.49445 
    funcionObjetivo = Rosenbrock
    intervalo = intervaloRosenbrock

    # Lista para contar cuántas veces la mejor solución se salió del rango
    mejor_adentro_que_afuera = np.zeros(ejecuciones)

    for j in range(ejecuciones):
        # Generar semilla única para cada ejecución
        seed = int(time.time()) % (2**32)
        seed += j
        np.random.seed(seed)

        # Ejecutar el algoritmo PSO
        aptitud_mejor, aptitud_promedio, contador_fuera_de_rango, ultima_iteracion_en_rango, _ = PSO_Estadistico(
            funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2
        )

        # Convertir `contador_fuera_de_rango` y `ultima_iteracion_en_rango` en listas para coincidir en longitud con los otros resultados
        contador_fuera_de_rango_arr = np.full_like(aptitud_mejor, contador_fuera_de_rango)
        ultima_iteracion_en_rango_arr = np.full_like(aptitud_mejor, ultima_iteracion_en_rango)

        # Guardar resultados en un archivo CSV para cada ejecución
        nombre_archivo = f"Rosenbrock_PSO_{j+1}_semilla_{seed}.csv"
        header = "MejorEval,PromedioEval,ContadorFueraDeRango,UltimaEnRango"

        # Apilar todos los resultados en columnas
        datos = np.column_stack((aptitud_mejor, aptitud_promedio, contador_fuera_de_rango_arr, ultima_iteracion_en_rango_arr))

        # Guardar los datos en un archivo CSV
        np.savetxt(nombre_archivo, datos, delimiter=',', header=header, comments='', fmt='%.6f,%.6f,%d,%s')

# Ejecutar el algoritmo y guardar los resultados
ejecutar_algoritmo_y_guardar_resultados()

# %%
import time
import numpy as np

# Función principal para ejecutar el algoritmo 30 veces y guardar los resultados
def ejecutar_algoritmo_y_guardar_resultados(ejecuciones=30):
    numParticulas = 70  # Tamaño de la población
    maxIteraciones = 1000  # Número de iteraciones
    dimension = 10  # Dimensionalidad del problema
    w = 0.729
    c1 = 1.49445
    c2 = 1.49445 
    funcionObjetivo = Ackley
    intervalo = intervaloAckley

    # Lista para contar cuántas veces la mejor solución se salió del rango
    mejor_adentro_que_afuera = np.zeros(ejecuciones)

    for j in range(ejecuciones):
        # Generar semilla única para cada ejecución
        seed = int(time.time()) % (2**32)
        seed += j
        np.random.seed(seed)

        # Ejecutar el algoritmo PSO
        aptitud_mejor, aptitud_promedio, contador_fuera_de_rango, ultima_iteracion_en_rango, _ = PSO_Estadistico(
            funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2
        )

        # Convertir `contador_fuera_de_rango` y `ultima_iteracion_en_rango` en listas para coincidir en longitud con los otros resultados
        contador_fuera_de_rango_arr = np.full_like(aptitud_mejor, contador_fuera_de_rango)
        ultima_iteracion_en_rango_arr = np.full_like(aptitud_mejor, ultima_iteracion_en_rango)

        # Guardar resultados en un archivo CSV para cada ejecución
        nombre_archivo = f"Ackley_PSO_{j+1}_semilla_{seed}.csv"
        header = "MejorEval,PromedioEval,ContadorFueraDeRango,UltimaEnRango"

        # Apilar todos los resultados en columnas
        datos = np.column_stack((aptitud_mejor, aptitud_promedio, contador_fuera_de_rango_arr, ultima_iteracion_en_rango_arr))

        # Guardar los datos en un archivo CSV
        np.savetxt(nombre_archivo, datos, delimiter=',', header=header, comments='', fmt='%.6f,%.6f,%d,%s')

# Ejecutar el algoritmo y guardar los resultados
ejecutar_algoritmo_y_guardar_resultados()

# %%
import time
import numpy as np

# Función principal para ejecutar el algoritmo 30 veces y guardar los resultados
def ejecutar_algoritmo_y_guardar_resultados(ejecuciones=30):
    numParticulas = 70  # Tamaño de la población
    maxIteraciones = 1000  # Número de iteraciones
    dimension = 10  # Dimensionalidad del problema
    w = 0.729
    c1 = 1.49445
    c2 = 1.49445 
    funcionObjetivo = Griewank
    intervalo = intervaloGriewank

    # Lista para contar cuántas veces la mejor solución se salió del rango
    mejor_adentro_que_afuera = np.zeros(ejecuciones)

    for j in range(ejecuciones):
        # Generar semilla única para cada ejecución
        seed = int(time.time()) % (2**32)
        seed += j
        np.random.seed(seed)

        # Ejecutar el algoritmo PSO
        aptitud_mejor, aptitud_promedio, contador_fuera_de_rango, ultima_iteracion_en_rango, _ = PSO_Estadistico(
            funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2
        )

        # Convertir `contador_fuera_de_rango` y `ultima_iteracion_en_rango` en listas para coincidir en longitud con los otros resultados
        contador_fuera_de_rango_arr = np.full_like(aptitud_mejor, contador_fuera_de_rango)
        ultima_iteracion_en_rango_arr = np.full_like(aptitud_mejor, ultima_iteracion_en_rango)

        # Guardar resultados en un archivo CSV para cada ejecución
        nombre_archivo = f"Griewank_PSO_{j+1}_semilla_{seed}.csv"
        header = "MejorEval,PromedioEval,ContadorFueraDeRango,UltimaEnRango"

        # Apilar todos los resultados en columnas
        datos = np.column_stack((aptitud_mejor, aptitud_promedio, contador_fuera_de_rango_arr, ultima_iteracion_en_rango_arr))

        # Guardar los datos en un archivo CSV
        np.savetxt(nombre_archivo, datos, delimiter=',', header=header, comments='', fmt='%.6f,%.6f,%d,%s')

# Ejecutar el algoritmo y guardar los resultados
ejecutar_algoritmo_y_guardar_resultados()

# %%
import time
import numpy as np

# Función principal para ejecutar el algoritmo 30 veces y guardar los resultados
def ejecutar_algoritmo_y_guardar_resultados(ejecuciones=30):
    numParticulas = 70  # Tamaño de la población
    maxIteraciones = 1000  # Número de iteraciones
    dimension = 10  # Dimensionalidad del problema
    w = 0.729
    c1 = 1.49445
    c2 = 1.49445 
    funcionObjetivo = Rastrigin
    intervalo = intervaloRastrigin

    # Lista para contar cuántas veces la mejor solución se salió del rango
    mejor_adentro_que_afuera = np.zeros(ejecuciones)

    for j in range(ejecuciones):
        # Generar semilla única para cada ejecución
        seed = int(time.time()) % (2**32)
        seed += j
        np.random.seed(seed)

        # Ejecutar el algoritmo PSO
        aptitud_mejor, aptitud_promedio, contador_fuera_de_rango, ultima_iteracion_en_rango, _ = PSO_Estadistico(
            funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2
        )

        # Convertir `contador_fuera_de_rango` y `ultima_iteracion_en_rango` en listas para coincidir en longitud con los otros resultados
        contador_fuera_de_rango_arr = np.full_like(aptitud_mejor, contador_fuera_de_rango)
        ultima_iteracion_en_rango_arr = np.full_like(aptitud_mejor, ultima_iteracion_en_rango)

        # Guardar resultados en un archivo CSV para cada ejecución
        nombre_archivo = f"Rastrigin_PSO_{j+1}_semilla_{seed}.csv"
        header = "MejorEval,PromedioEval,ContadorFueraDeRango,UltimaEnRango"

        # Apilar todos los resultados en columnas
        datos = np.column_stack((aptitud_mejor, aptitud_promedio, contador_fuera_de_rango_arr, ultima_iteracion_en_rango_arr))

        # Guardar los datos en un archivo CSV
        np.savetxt(nombre_archivo, datos, delimiter=',', header=header, comments='', fmt='%.6f,%.6f,%d,%s')

# Ejecutar el algoritmo y guardar los resultados
ejecutar_algoritmo_y_guardar_resultados()

# %%
import time
import numpy as np

# Función principal para ejecutar el algoritmo 30 veces y guardar los resultados
def ejecutar_algoritmo_y_guardar_resultados(ejecuciones=30):
    numParticulas = 70  # Tamaño de la población
    maxIteraciones = 1000  # Número de iteraciones
    dimension = 10  # Dimensionalidad del problema
    w = 0.729
    c1 = 1.49445
    c2 = 1.49445 
    funcionObjetivo = Sphere
    intervalo = intervaloSphere

    # Lista para contar cuántas veces la mejor solución se salió del rango
    mejor_adentro_que_afuera = np.zeros(ejecuciones)

    for j in range(ejecuciones):
        # Generar semilla única para cada ejecución
        seed = int(time.time()) % (2**32)
        seed += j
        np.random.seed(seed)

        # Ejecutar el algoritmo PSO
        aptitud_mejor, aptitud_promedio, contador_fuera_de_rango, ultima_iteracion_en_rango, _ = PSO_Estadistico(
            funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2
        )

        # Convertir `contador_fuera_de_rango` y `ultima_iteracion_en_rango` en listas para coincidir en longitud con los otros resultados
        contador_fuera_de_rango_arr = np.full_like(aptitud_mejor, contador_fuera_de_rango)
        ultima_iteracion_en_rango_arr = np.full_like(aptitud_mejor, ultima_iteracion_en_rango)

        # Guardar resultados en un archivo CSV para cada ejecución
        nombre_archivo = f"Sphere_PSO_{j+1}_semilla_{seed}.csv"
        header = "MejorEval,PromedioEval,ContadorFueraDeRango,UltimaEnRango"

        # Apilar todos los resultados en columnas
        datos = np.column_stack((aptitud_mejor, aptitud_promedio, contador_fuera_de_rango_arr, ultima_iteracion_en_rango_arr))

        # Guardar los datos en un archivo CSV
        np.savetxt(nombre_archivo, datos, delimiter=',', header=header, comments='', fmt='%.6f,%.6f,%d,%s')

# Ejecutar el algoritmo y guardar los resultados
ejecutar_algoritmo_y_guardar_resultados()

# %% [markdown]
# **Tabla PSO:**

# %%
import os
import pandas as pd

# Directorio base donde se encuentran las carpetas de funciones
base_dir = r"C:\Users\Chinitok666\Documents\GitHub\C-mputo-Evolutivo-primeros-intentos\PSO"

# Lista de nombres de las carpetas para cada función
funciones = ['Ejecuciones_Ackley', 'Ejecuciones_Griewank', 'Ejecuciones_Rastrigin', 'Ejecuciones_Rosenbrock', 'Ejecuciones_Sphere']

# Lista para almacenar los resultados de cada función
resultados = []

# Recorrer cada carpeta de función
for funcion in funciones:
    carpeta_funcion = os.path.join(base_dir, funcion)
    valores_mejor_eval = []
    dentro_rango = 0  # Contador de ejecuciones dentro del rango

    # Verificar si la carpeta existe
    if not os.path.exists(carpeta_funcion):
        print(f"Carpeta no encontrada: {carpeta_funcion}")
        continue

    print(f"\nProcesando función: {funcion}")
    
    # Procesar cada archivo CSV en la carpeta de la función
    archivos_encontrados = 0
    for archivo in os.listdir(carpeta_funcion):
        if archivo.endswith('.csv'):
            archivos_encontrados += 1
            
            # Leer el archivo CSV
            archivo_path = os.path.join(carpeta_funcion, archivo)
            df = pd.read_csv(archivo_path)
            
            # Verificar que el archivo no esté vacío
            if df.empty:
                print(f"Archivo vacío: {archivo_path}")
                continue
            
            # Extraer el valor de la última fila de la primera columna (MejorEval)
            try:
                mejor_eval = df.iloc[-1, 0]
                valores_mejor_eval.append(mejor_eval)
                print(f"  {archivo}: MejorEval final = {mejor_eval}")
            except IndexError:
                print(f"  Error al leer MejorEval en {archivo_path}")
                continue
            
            # Comprobar si la última fila de 'UltimaEnRango' es 1 (en rango)
            try:
                ultima_en_rango = df.iloc[-1, -1]  # Última columna
                if ultima_en_rango == 1:
                    dentro_rango += 1
            except IndexError:
                print(f"  Error al leer UltimaEnRango en {archivo_path}")

    if archivos_encontrados == 0:
        print(f"No se encontraron archivos CSV en {carpeta_funcion}")
        continue

    # Calcular estadísticas solo si hay datos
    if valores_mejor_eval:
        mejor_valor = min(valores_mejor_eval)
        promedio = sum(valores_mejor_eval) / len(valores_mejor_eval)
        peor_valor = max(valores_mejor_eval)
        mediana = pd.Series(valores_mejor_eval).median()
        desviacion_std = pd.Series(valores_mejor_eval).std()
        porcentaje_dentro_rango = (dentro_rango / len(valores_mejor_eval)) * 100

        # Almacenar resultados
        resultados.append({
            'Funcion': funcion,
            'Mejor Valor': mejor_valor,
            'Promedio': promedio,
            'Peor Valor': peor_valor,
            'Mediana': mediana,
            'Desviación Estándar': desviacion_std,
            'Porcentaje en Rango': porcentaje_dentro_rango
        })
    else:
        print(f"No se encontraron datos válidos para la función: {funcion}")

# Crear un DataFrame y guardarlo como CSV
df_resultados = pd.DataFrame(resultados)
if not df_resultados.empty:
    df_resultados.to_csv('resultados_estadisticos.csv', index=False)
    print("\nArchivo 'resultados_estadisticos.csv' generado con éxito.")
else:
    print("\nNo se generaron resultados estadísticos, la tabla está vacía.")
# Out:
# Procesando función: Ejecuciones_Ackley
#   Ackley_PSO_10_semilla_1730873128.csv: MejorEval final = 0.0
#   Ackley_PSO_11_semilla_1730873129.csv: MejorEval final = 0.0
#   Ackley_PSO_12_semilla_1730873130.csv: MejorEval final = 0.0
#   Ackley_PSO_13_semilla_1730873131.csv: MejorEval final = 0.0
#   Ackley_PSO_14_semilla_1730873132.csv: MejorEval final = 0.0
#   Ackley_PSO_15_semilla_1730873133.csv: MejorEval final = 0.0
#   Ackley_PSO_16_semilla_1730873134.csv: MejorEval final = 0.0
#   Ackley_PSO_17_semilla_1730873135.csv: MejorEval final = 0.0
#   Ackley_PSO_18_semilla_1730873136.csv: MejorEval final = 0.0
#   Ackley_PSO_19_semilla_1730873137.csv: MejorEval final = 0.0
#   Ackley_PSO_1_semilla_1730873118.csv: MejorEval final = 0.0
#   Ackley_PSO_20_semilla_1730873138.csv: MejorEval final = 0.0
#   Ackley_PSO_21_semilla_1730873139.csv: MejorEval final = 0.0
#   Ackley_PSO_22_semilla_1730873140.csv: MejorEval final = 0.0
#   Ackley_PSO_23_semilla_1730873141.csv: MejorEval final = 0.0
#   Ackley_PSO_24_semilla_1730873142.csv: MejorEval final = 0.0
#   Ackley_PSO_25_semilla_1730873143.csv: MejorEval final = 0.0
#   Ackley_PSO_26_semilla_1730873144.csv: MejorEval final = 0.0
#   Ackley_PSO_27_semilla_1730873145.csv: MejorEval final = 0.0
#   Ackley_PSO_28_semilla_1730873146.csv: MejorEval final = 0.0
#   Ackley_PSO_29_semilla_1730873147.csv: MejorEval final = 0.0
#   Ackley_PSO_2_semilla_1730873120.csv: MejorEval final = 0.0
#   Ackley_PSO_30_semilla_1730873148.csv: MejorEval final = 0.0
#   Ackley_PSO_3_semilla_1730873121.csv: MejorEval final = 0.0
#   Ackley_PSO_4_semilla_1730873122.csv: MejorEval final = 0.0
#   Ackley_PSO_5_semilla_1730873123.csv: MejorEval final = 0.0
#   Ackley_PSO_6_semilla_1730873124.csv: MejorEval final = 0.0
#   Ackley_PSO_7_semilla_1730873125.csv: MejorEval final = 0.0
#   Ackley_PSO_8_semilla_1730873126.csv: MejorEval final = 0.0
#   Ackley_PSO_9_semilla_1730873127.csv: MejorEval final = 0.0
#
# Procesando función: Ejecuciones_Griewank
#   Griewank_PSO_10_semilla_1730873260.csv: MejorEval final = 0.098389
#   Griewank_PSO_11_semilla_1730873261.csv: MejorEval final = 0.100816
#   Griewank_PSO_12_semilla_1730873262.csv: MejorEval final = 0.012321
#   Griewank_PSO_13_semilla_1730873263.csv: MejorEval final = 0.05657
#   Griewank_PSO_14_semilla_1730873264.csv: MejorEval final = 0.095859
#   Griewank_PSO_15_semilla_1730873265.csv: MejorEval final = 0.073762
#   Griewank_PSO_16_semilla_1730873266.csv: MejorEval final = 0.039441
#   Griewank_PSO_17_semilla_1730873267.csv: MejorEval final = 0.083705
#   Griewank_PSO_18_semilla_1730873268.csv: MejorEval final = 0.049183
#   Griewank_PSO_19_semilla_1730873269.csv: MejorEval final = 0.078797
#   Griewank_PSO_1_semilla_1730873251.csv: MejorEval final = 0.044298
#   Griewank_PSO_20_semilla_1730873270.csv: MejorEval final = 0.113425
#   Griewank_PSO_21_semilla_1730873272.csv: MejorEval final = 0.145071
#   Griewank_PSO_22_semilla_1730873273.csv: MejorEval final = 0.059029
#   Griewank_PSO_23_semilla_1730873274.csv: MejorEval final = 0.02459
#   Griewank_PSO_24_semilla_1730873275.csv: MejorEval final = 0.100771
#   Griewank_PSO_25_semilla_1730873276.csv: MejorEval final = 0.044268
#   Griewank_PSO_26_semilla_1730873277.csv: MejorEval final = 0.049282
#   Griewank_PSO_27_semilla_1730873278.csv: MejorEval final = 0.044254
#   Griewank_PSO_28_semilla_1730873279.csv: MejorEval final = 0.120702
#   Griewank_PSO_29_semilla_1730873280.csv: MejorEval final = 0.046796
#   Griewank_PSO_2_semilla_1730873252.csv: MejorEval final = 0.088573
#   Griewank_PSO_30_semilla_1730873281.csv: MejorEval final = 0.076259
#   Griewank_PSO_3_semilla_1730873253.csv: MejorEval final = 0.093442
#   Griewank_PSO_4_semilla_1730873254.csv: MejorEval final = 0.046747
#   Griewank_PSO_5_semilla_1730873255.csv: MejorEval final = 0.078706
#   Griewank_PSO_6_semilla_1730873256.csv: MejorEval final = 0.066405
#   Griewank_PSO_7_semilla_1730873257.csv: MejorEval final = 0.027037
#   Griewank_PSO_8_semilla_1730873258.csv: MejorEval final = 0.068856
#   Griewank_PSO_9_semilla_1730873259.csv: MejorEval final = 0.073786
#
# Procesando función: Ejecuciones_Rastrigin
#   Rastrigin_PSO_10_semilla_1730873436.csv: MejorEval final = 4.974795
#   Rastrigin_PSO_11_semilla_1730873437.csv: MejorEval final = 3.979836
#   Rastrigin_PSO_12_semilla_1730873438.csv: MejorEval final = 2.984877
#   Rastrigin_PSO_13_semilla_1730873439.csv: MejorEval final = 1.989918
#   Rastrigin_PSO_14_semilla_1730873440.csv: MejorEval final = 2.984877
#   Rastrigin_PSO_15_semilla_1730873441.csv: MejorEval final = 5.969749
#   Rastrigin_PSO_16_semilla_1730873442.csv: MejorEval final = 4.974795
#   Rastrigin_PSO_17_semilla_1730873443.csv: MejorEval final = 3.979836
#   Rastrigin_PSO_18_semilla_1730873444.csv: MejorEval final = 1.989918
#   Rastrigin_PSO_19_semilla_1730873445.csv: MejorEval final = 5.969754
#   Rastrigin_PSO_1_semilla_1730873426.csv: MejorEval final = 3.979836
#   Rastrigin_PSO_20_semilla_1730873446.csv: MejorEval final = 4.974795
#   Rastrigin_PSO_21_semilla_1730873447.csv: MejorEval final = 2.984877
#   Rastrigin_PSO_22_semilla_1730873448.csv: MejorEval final = 2.984877
#   Rastrigin_PSO_23_semilla_1730873449.csv: MejorEval final = 6.964708
#   Rastrigin_PSO_24_semilla_1730873450.csv: MejorEval final = 2.984877
#   Rastrigin_PSO_25_semilla_1730873451.csv: MejorEval final = 4.974795
#   Rastrigin_PSO_26_semilla_1730873452.csv: MejorEval final = 5.969749
#   Rastrigin_PSO_27_semilla_1730873453.csv: MejorEval final = 5.96975
#   Rastrigin_PSO_28_semilla_1730873454.csv: MejorEval final = 9.94958
#   Rastrigin_PSO_29_semilla_1730873455.csv: MejorEval final = 4.974795
#   Rastrigin_PSO_2_semilla_1730873428.csv: MejorEval final = 3.979836
#   Rastrigin_PSO_30_semilla_1730873456.csv: MejorEval final = 2.984877
#   Rastrigin_PSO_3_semilla_1730873429.csv: MejorEval final = 5.969749
#   Rastrigin_PSO_4_semilla_1730873430.csv: MejorEval final = 5.969754
#   Rastrigin_PSO_5_semilla_1730873431.csv: MejorEval final = 3.979836
#   Rastrigin_PSO_6_semilla_1730873432.csv: MejorEval final = 3.979836
#   Rastrigin_PSO_7_semilla_1730873433.csv: MejorEval final = 3.979836
#   Rastrigin_PSO_8_semilla_1730873434.csv: MejorEval final = 5.969754
#   Rastrigin_PSO_9_semilla_1730873435.csv: MejorEval final = 6.964708
#
# Procesando función: Ejecuciones_Rosenbrock
#   Rosenbrock_PSO_10_semilla_1730872884.csv: MejorEval final = 1.952434
#   Rosenbrock_PSO_11_semilla_1730872885.csv: MejorEval final = 1.480208
#   Rosenbrock_PSO_12_semilla_1730872886.csv: MejorEval final = 1.747879
#   Rosenbrock_PSO_13_semilla_1730872887.csv: MejorEval final = 1.357021
#   Rosenbrock_PSO_14_semilla_1730872888.csv: MejorEval final = 2.062003
#   Rosenbrock_PSO_15_semilla_1730872889.csv: MejorEval final = 4.210855
#   Rosenbrock_PSO_16_semilla_1730872890.csv: MejorEval final = 1.357164
#   Rosenbrock_PSO_17_semilla_1730872891.csv: MejorEval final = 1.827735
#   Rosenbrock_PSO_18_semilla_1730872892.csv: MejorEval final = 2.199756
#   Rosenbrock_PSO_19_semilla_1730872893.csv: MejorEval final = 1.526566
#   Rosenbrock_PSO_1_semilla_1730872875.csv: MejorEval final = 1.729513
#   Rosenbrock_PSO_20_semilla_1730872894.csv: MejorEval final = 1.587258
#   Rosenbrock_PSO_21_semilla_1730872895.csv: MejorEval final = 2.505763
#   Rosenbrock_PSO_22_semilla_1730872896.csv: MejorEval final = 4.245099
#   Rosenbrock_PSO_23_semilla_1730872897.csv: MejorEval final = 0.617773
#   Rosenbrock_PSO_24_semilla_1730872898.csv: MejorEval final = 1.337866
#   Rosenbrock_PSO_25_semilla_1730872899.csv: MejorEval final = 0.036444
#   Rosenbrock_PSO_26_semilla_1730872900.csv: MejorEval final = 1.394576
#   Rosenbrock_PSO_27_semilla_1730872902.csv: MejorEval final = 1.639729
#   Rosenbrock_PSO_28_semilla_1730872903.csv: MejorEval final = 5.227418
#   Rosenbrock_PSO_29_semilla_1730872904.csv: MejorEval final = 1.642705
#   Rosenbrock_PSO_2_semilla_1730872876.csv: MejorEval final = 2.090681
#   Rosenbrock_PSO_30_semilla_1730872905.csv: MejorEval final = 1.16554
#   Rosenbrock_PSO_3_semilla_1730872877.csv: MejorEval final = 1.287176
#   Rosenbrock_PSO_4_semilla_1730872878.csv: MejorEval final = 1.067045
#   Rosenbrock_PSO_5_semilla_1730872879.csv: MejorEval final = 1.388523
#   Rosenbrock_PSO_6_semilla_1730872880.csv: MejorEval final = 0.942185
#   Rosenbrock_PSO_7_semilla_1730872881.csv: MejorEval final = 1.757807
#   Rosenbrock_PSO_8_semilla_1730872882.csv: MejorEval final = 2.076803
#   Rosenbrock_PSO_9_semilla_1730872883.csv: MejorEval final = 1.922799
#
# Procesando función: Ejecuciones_Sphere
#   Sphere_PSO_10_semilla_1730873570.csv: MejorEval final = 0.0
#   Sphere_PSO_11_semilla_1730873571.csv: MejorEval final = 0.0
#   Sphere_PSO_12_semilla_1730873572.csv: MejorEval final = 0.0
#   Sphere_PSO_13_semilla_1730873573.csv: MejorEval final = 0.0
#   Sphere_PSO_14_semilla_1730873574.csv: MejorEval final = 0.0
#   Sphere_PSO_15_semilla_1730873575.csv: MejorEval final = 0.0
#   Sphere_PSO_16_semilla_1730873576.csv: MejorEval final = 0.0
#   Sphere_PSO_17_semilla_1730873577.csv: MejorEval final = 0.0
#   Sphere_PSO_18_semilla_1730873578.csv: MejorEval final = 0.0
#   Sphere_PSO_19_semilla_1730873579.csv: MejorEval final = 0.0
#   Sphere_PSO_1_semilla_1730873560.csv: MejorEval final = 0.0
#   Sphere_PSO_20_semilla_1730873580.csv: MejorEval final = 0.0
#   Sphere_PSO_21_semilla_1730873581.csv: MejorEval final = 0.0
#   Sphere_PSO_22_semilla_1730873582.csv: MejorEval final = 0.0
#   Sphere_PSO_23_semilla_1730873583.csv: MejorEval final = 0.0
#   Sphere_PSO_24_semilla_1730873584.csv: MejorEval final = 0.0
#   Sphere_PSO_25_semilla_1730873585.csv: MejorEval final = 0.0
#   Sphere_PSO_26_semilla_1730873586.csv: MejorEval final = 0.0
#   Sphere_PSO_27_semilla_1730873587.csv: MejorEval final = 0.0
#   Sphere_PSO_28_semilla_1730873588.csv: MejorEval final = 0.0
#   Sphere_PSO_29_semilla_1730873589.csv: MejorEval final = 0.0
#   Sphere_PSO_2_semilla_1730873562.csv: MejorEval final = 0.0
#   Sphere_PSO_30_semilla_1730873590.csv: MejorEval final = 0.0
#   Sphere_PSO_3_semilla_1730873563.csv: MejorEval final = 0.0
#   Sphere_PSO_4_semilla_1730873564.csv: MejorEval final = 0.0
#   Sphere_PSO_5_semilla_1730873565.csv: MejorEval final = 0.0
#   Sphere_PSO_6_semilla_1730873566.csv: MejorEval final = 0.0
#   Sphere_PSO_7_semilla_1730873567.csv: MejorEval final = 0.0
#   Sphere_PSO_8_semilla_1730873568.csv: MejorEval final = 0.0
#   Sphere_PSO_9_semilla_1730873569.csv: MejorEval final = 0.0
#
# Archivo 'resultados_estadisticos.csv' generado con éxito.

# %% [markdown]
# **PSO que no se sale del espacio de búsqueda:**

# %%
@numba.njit
def PSO_Estadistico(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2):

    # Inicializamos listas donde guardaremos las iteraciones 
    aptitud_promedio = np.zeros(maxIteraciones)
    aptitud_mejor = np.zeros(maxIteraciones)
    
    # Inicializamos nuestra población inicial de partículas y velocidades:
    a, b = intervalo
    particulas = np.random.uniform(a, b, (numParticulas, dimension))
    velocidades = np.zeros((numParticulas, dimension))

    # Inicializamos las mejores posiciones y mejores valores:
    mejores_posiciones = np.copy(particulas)
    mejores_aptitudes = np.empty(numParticulas)
    for i in range(numParticulas):
        mejores_aptitudes[i] = funcionObjetivo(particulas[i])

    mejor_posicion_enjambre = mejores_posiciones[np.argmin(mejores_aptitudes)]
    mejor_aptitud_enjambre = np.min(mejores_aptitudes)

    # Iteramos hasta maxIteraciones, actualizando la velocidad y la posición de cada partícula en cada iteración:
    for iteracion in range(maxIteraciones):
        # Actualizamos las velocidades:
        r1 = np.random.uniform(0, 1, (numParticulas, dimension))
        r2 = np.random.uniform(0, 1, (numParticulas, dimension))
        for i in range(numParticulas):
            for d in range(dimension):
                velocidades[i, d] = (w * velocidades[i, d] + 
                                     c1 * r1[i, d] * (mejores_posiciones[i, d] - particulas[i, d]) +
                                     c2 * r2[i, d] * (mejor_posicion_enjambre[d] - particulas[i, d]))

        # Actualizamos las posiciones:
        for i in range(numParticulas):
            for d in range(dimension):
                particulas[i, d] += velocidades[i, d]

        # Aplicamos la restricción para mantener las partículas dentro del intervalo [a, b]
        particulas = np.clip(particulas, a, b)

        # Evaluamos la aptitud de cada partícula:
        evaluaciones_de_aptitud = np.empty(numParticulas)
        for i in range(numParticulas):
            evaluaciones_de_aptitud[i] = funcionObjetivo(particulas[i])

        # Actualizamos las posiciones y las aptitudes:
        for i in range(numParticulas):
            if evaluaciones_de_aptitud[i] < mejores_aptitudes[i]:
                mejores_aptitudes[i] = evaluaciones_de_aptitud[i]
                mejores_posiciones[i] = particulas[i]

        # Actualizamos la mejor posición global si es que encontramos una mejor:
        mejor_aptitud_actual = np.min(evaluaciones_de_aptitud)
        if mejor_aptitud_actual < mejor_aptitud_enjambre:
            mejor_aptitud_enjambre = mejor_aptitud_actual
            mejor_posicion_enjambre = particulas[np.argmin(evaluaciones_de_aptitud)]

        # Guardamos la mejor aptitud y el promedio de aptitud de la generación actual:
        aptitud_mejor[iteracion] = mejor_aptitud_enjambre
        aptitud_promedio[iteracion] = np.mean(evaluaciones_de_aptitud)

    # Retornamos la lista de las mejores soluciones encontradas en cada generación y la lista de los promedios generacionales:
    return aptitud_mejor, aptitud_promedio

# %%
numParticulas = 70 # Misma población que en AG para que la comparación sea justa.
maxIteraciones = 1000 # Mismas iteraciones que en AG para que la comparación sea justa.
dimension = 10 # Misma dimensión que en AG para que la comparación sea justa.
w = 0.729
c1 = 1.49445
c2 = 1.49445 
funcionObjetivo = Rastrigin
intervalo = intervaloRastrigin

PSO(funcionObjetivo, intervalo, dimension, numParticulas, maxIteraciones, w, c1, c2)
# Out:
# (array([-1.38439015e-09,  9.94958636e-01,  1.98991223e+00,  9.94958639e-01,
#         -9.94958637e-01,  9.94958639e-01, -5.35715289e-10,  5.80254525e-10,
#         -1.10228578e-09, -8.30956021e-10]),
#  7.959667418927239)
